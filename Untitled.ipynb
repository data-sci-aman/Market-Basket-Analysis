# %%
import pandas as pd
import numpy as np
#from mlxtend.preprocessing import OnehotTransactions
from sklearn.preprocessing import OneHotEncoder
from mlxtend.frequent_patterns import apriori,association_rules

# %%
all_txns=[]

with open('Groceries.csv') as f:
    content=f.readlines()
    txns=[x.strip() for x in content]
    
    for each_txn in txns:
        all_txns.append(each_txn.split(','))

# %%
all_txns[0:5]
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product']]

# %%
from mlxtend.preprocessing import TransactionEncoder
enc=TransactionEncoder()
enc_txns=enc.fit(all_txns).transform(all_txns)

# %%
enc_df=pd.DataFrame(enc_txns,columns=enc.columns_)

# %%
enc_df.shape
# Out:
# (9835, 169)

# %%
frequent_itemset=apriori(enc_df,min_support=0.02,use_colnames=True)

# %%
frequent_itemset.sample(10,random_state=90)
# Out:
#       support                            itemsets
# 60   0.020437          (bottled beer, whole milk)
# 52   0.033859                             (sugar)
# 89   0.035892  (other vegetables, tropical fruit)
# 105  0.021047   (tropical fruit, root vegetables)
# 88   0.032740            (other vegetables, soda)
# 16   0.058058                            (coffee)
# 111  0.024504         (whole milk, shopping bags)
# 36   0.079817                        (newspapers)
# 119  0.056024                (whole milk, yogurt)
# 55   0.071683                (whipped/sour cream)

# %%
rules=association_rules(frequent_itemset,
                       metric="lift",
                       min_threshold=1)

# %%
rules.sample(10)
# Out:
#                         antecedents          consequents  antecedent support  \
# 103                        (yogurt)               (soda)            0.139502
# 18               (other vegetables)       (citrus fruit)            0.193493
# 33                     (whole milk)  (frozen vegetables)            0.255516
# 71                 (tropical fruit)          (pip fruit)            0.104931
# 121  (other vegetables, whole milk)             (yogurt)            0.074835
# 77                (root vegetables)         (rolls/buns)            0.108998
# 19                   (citrus fruit)   (other vegetables)            0.082766
# 106                        (yogurt)     (tropical fruit)            0.139502
# 68                         (pastry)         (whole milk)            0.088968
# 40                     (whole milk)         (newspapers)            0.255516
#
#      consequent support   support  confidence      lift  leverage  conviction
# 103            0.174377  0.027351    0.196064  1.124368  0.003025    1.026976
# 18             0.082766  0.028876    0.149238  1.803140  0.012862    1.078133
# 33             0.048094  0.020437    0.079984  1.663094  0.008149    1.034663
# 71             0.075648  0.020437    0.194767  2.574648  0.012499    1.147931
# 121            0.139502  0.022267    0.297554  2.132979  0.011828    1.225003
# 77             0.183935  0.024301    0.222948  1.212101  0.004252    1.050206
# 19             0.193493  0.028876    0.348894  1.803140  0.012862    1.238674
# 106            0.104931  0.029283    0.209913  2.000475  0.014645    1.132873
# 68             0.255516  0.033249    0.373714  1.462587  0.010516    1.188729
# 40             0.079817  0.027351    0.107043  1.341110  0.006957    1.030490

# %%
rules.sort_values('confidence',ascending=False)[0:10]
# Out:
#                              antecedents         consequents  \
# 120           (other vegetables, yogurt)        (whole milk)
# 16                              (butter)        (whole milk)
# 24                                (curd)        (whole milk)
# 115  (other vegetables, root vegetables)        (whole milk)
# 116        (whole milk, root vegetables)  (other vegetables)
# 29                       (domestic eggs)        (whole milk)
# 108                 (whipped/sour cream)        (whole milk)
# 91                     (root vegetables)        (whole milk)
# 51                     (root vegetables)  (other vegetables)
# 32                   (frozen vegetables)        (whole milk)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 120            0.043416            0.255516  0.022267    0.512881  2.007235
# 16             0.055414            0.255516  0.027555    0.497248  1.946053
# 24             0.053279            0.255516  0.026131    0.490458  1.919481
# 115            0.047382            0.255516  0.023183    0.489270  1.914833
# 116            0.048907            0.193493  0.023183    0.474012  2.449770
# 29             0.063447            0.255516  0.029995    0.472756  1.850203
# 108            0.071683            0.255516  0.032232    0.449645  1.759754
# 91             0.108998            0.255516  0.048907    0.448694  1.756031
# 51             0.108998            0.193493  0.047382    0.434701  2.246605
# 32             0.048094            0.255516  0.020437    0.424947  1.663094
#
#      leverage  conviction
# 120  0.011174    1.528340
# 16   0.013395    1.480817
# 24   0.012517    1.461085
# 115  0.011076    1.457687
# 116  0.013719    1.533320
# 29   0.013783    1.412030
# 108  0.013916    1.352735
# 91   0.021056    1.350401
# 51   0.026291    1.426693
# 32   0.008149    1.294636
